# %%
import requests
import os
from tqdm import tqdm
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin, urlparse

def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def get_all_images(url):
    """
    Returns all image URLs on a single `url`
    """
    soup = bs(requests.get(url).content, "html.parser")
    
    urls = []
    for img in tqdm(soup.find_all("img"), "Extracting images"):
        img_url = img.attrs.get("src")
        if not img_url:
            # if img does not contain src attribute, just skip
            continue
        
        # make the URL absolute by joining domain with the URL that is just extracted
        img_url = urljoin(url, img_url)
        
        try:
            pos = img_url.index("?")
            img_url = img_url[:pos]
        except ValueError:
            pass
        
        # finally, if the url is valid
        if is_valid(img_url):
            urls.append(img_url)
    return urls

def download(url, pathname):
    """
    Downloads a file given an URL and puts it in the folder `pathname`
    """
    # if path doesn't exist, make that path dir
    if not os.path.isdir(pathname):
        os.makedirs(pathname)
    # download the body of response by chunk, not immediately
    response = requests.get(url, stream=True)
    # get the total file size
    file_size = int(response.headers.get("Content-Length", 0))
    # get the file name
    filename = os.path.join(pathname, url.split("/")[-1])
    # progress bar, changing the unit to bytes instead of iteration (default by tqdm)
    progress = tqdm(response.iter_content(1024), f"Downloading {filename}", total=file_size, unit="B", unit_scale=True, unit_divisor=1024)
    with open(filename, "wb") as f:
        for data in progress.iterable:
            # write data read to the file
            f.write(data)
            # update the progress bar manually
            progress.update(len(data))

"""
 "main" is the function that is actually scraping and downloading the images off a specified website
 input: a url and a directory path
 output/result: images are downloaded into specific folder
 everything above is used in main
"""           
def main(url, path):
    # get all images
    imgs = get_all_images(url)
    for img in imgs:
        # for each image, download it
        download(img, path)

"""
example of how to run main to download images      
main("https://www.csulb.edu/college-of-education", "C:\\Users\\hanse\\Documents\\Github\\Algorithmic-Bias\\Web-Scraping\\image-folder")
"""
# Out:
# '\nexample of how to run main to download images      \nmain("https://www.csulb.edu/college-of-education", "C:\\Users\\hanse\\Documents\\Github\\Algorithmic-Bias\\Web-Scraping\\image-folder")\n'

# %%
from bs4 import BeautifulSoup
import requests

def get_embedded_url(url):
    """
    extracts all links embedded in 'url' that contain "college-of-education"
    stores the links in the list 'observed_links'
    """
    page = requests.get(url)    
    data = page.text
    soup = BeautifulSoup(data)

    # this is creating the list of urls that are embedded in college of ed homepage that we want to look into
    observed_links = []
    for link in soup.find_all('a'):
        if 'college-of-education' in link.get('href'):
            if 'https://www.csulb.edu' in link.get('href'):
                observed_links.append(link.get('href'))
            elif link.get('href')[:1] == '/':
                https_concat = 'https://www.csulb.edu'+(link.get('href'))
                observed_links.append(https_concat)
    observed_links = list(set(observed_links))
    return observed_links

# %%
observed_links = get_embedded_url("https://www.csulb.edu/college-of-education")

# %%
# display the list of links generated above, what does it "physically" look like?
display(observed_links)

# display the number of links that were extracted using get_embedded_url
display(len(observed_links))

# count the number of "valid" or executable links in the observed
count = 0
for i in observed_links:
    if is_valid(i):
        count += 1
count
# Out:
# ['https://www.csulb.edu/college-of-education/teacher-education',
#  'https://www.csulb.edu/college-of-education/assessment-office',
#  'https://www.csulb.edu/college-of-education/become-a-counselor-or-psychologist',
#  'https://www.csulb.edu/college-of-education/education-specialist-credential-program-escp',
#  'https://www.csulb.edu/college-of-education/community-clinic-for-counseling-and-educational-services',
#  'https://www.csulb.edu/college-of-education/liberal-studies',
#  'https://www.csulb.edu/college-of-education/dual-language-development',
#  'https://www.csulb.edu/college-of-education/overview-of-scholarships-financial-aid',
#  'https://www.csulb.edu/college-of-education/multiple-subject-credential-program-mscp',
#  'https://www.csulb.edu/college-of-education/faculty-and-staff-celebrated-at-convocation',
#  'https://www.csulb.edu/college-of-education/equity-education-and-social-justice',
#  'https://www.csulb.edu/college-of-education/counseling-psychology',
#  'https://www.csulb.edu/college-of-education/school-psychology',
#  'https://www.csulb.edu/college-of-education',
#  'https://www.csulb.edu/college-of-education/single-subject-credential-program-sscp',
#  'https://www.csulb.edu/college-of-education/office-of-the-dean/college-and-university-tools',
#  'https://www.csulb.edu/college-of-education/make-an-appointment',
#  'https://www.csulb.edu/college-of-education/advanced-studies-education-and-counseling',
#  'https://www.csulb.edu/college-of-education/events',
#  'https://www.csulb.edu/college-of-education/urban-dual-credential-program-udcp',
#  'https://www.csulb.edu/college-of-education/employment-opportunities',
#  'https://www.csulb.edu/college-of-education/article/summit-give-your-schools-a-boost-of-joy',
#  'https://www.csulb.edu/college-of-education/outreach-and-recruitment/program-information-sessions',
#  'https://www.csulb.edu/college-of-education/faculty-resources-and-support',
#  'https://www.csulb.edu/college-of-education/hsi-caminos-project-caminantes-for-education',
#  'https://www.csulb.edu/college-of-education/article/prolific-fundraiser-known-for-gentle-persistence-retires',
#  'https://www.csulb.edu/college-of-education/teaching-and-learning-portal',
#  'https://www.csulb.edu/college-of-education/credential-center/credential-programs',
#  'https://www.csulb.edu/college-of-education/about-the-college',
#  'https://www.csulb.edu/college-of-education/school-counseling',
#  'https://www.csulb.edu/college-of-education/article/college-awarded-39-million-to-improve-youth-mental-health',
#  'https://www.csulb.edu/college-of-education/educational-doctorate-educational-leadership',
#  'https://www.csulb.edu/college-of-education/outreach-and-recruitment/interested-visiting-the-college-of-education',
#  'https://www.csulb.edu/college-of-education/fiscal-office',
#  'https://www.csulb.edu/college-of-education/outreach-and-recruitment',
#  'https://www.csulb.edu/college-of-education/policies-and-forms',
#  'https://www.csulb.edu/college-of-education/message-the-dean',
#  'https://www.csulb.edu/college-of-education/graduate-studies-office',
#  'https://www.csulb.edu/college-of-education/teacher-librarian-services-credential',
#  'https://www.csulb.edu/college-of-education/become-an-educational-leader',
#  'https://www.csulb.edu/college-of-education/teacher-preparation-advising-center-tpac',
#  'https://www.csulb.edu/college-of-education/explore-our-programs',
#  'https://www.csulb.edu/college-of-education/university-college-student-resources',
#  'https://www.csulb.edu/college-of-education/educational-administration',
#  'https://www.csulb.edu/college-of-education/contact-us',
#  'https://www.csulb.edu/college-of-education/office-of-the-dean',
#  'https://www.csulb.edu/college-of-education/development-office',
#  'https://www.csulb.edu/college-of-education/early-childhood-education',
#  'https://www.csulb.edu/college-of-education/admissions-and-how-apply',
#  'https://www.csulb.edu/college-of-education/form/share-your-faculty-andor-staff-updates-and-accolades',
#  'https://www.csulb.edu/college-of-education/credential-center/careers-education',
#  'https://www.csulb.edu/college-of-education/curriculum-and-instruction',
#  'https://www.csulb.edu/college-of-education/ced-accreditation-launchpad',
#  'https://www.csulb.edu/college-of-education/alumni',
#  'https://www.csulb.edu/college-of-education/educational-technology-and-media-leadership',
#  'https://www.csulb.edu/college-of-education/liberal-studies/prospective-students',
#  'https://www.csulb.edu/college-of-education/student-development-higher-education',
#  'https://www.csulb.edu/college-of-education/spotlights',
#  'https://www.csulb.edu/college-of-education/long-beach-trauma-recovery-center',
#  'https://www.csulb.edu/college-of-education/mathematics-education',
#  'https://www.csulb.edu/college-of-education/center-for-evaluation-and-educational-effectiveness',
#  'https://www.csulb.edu/college-of-education/liberal-studies/liberal-studies-program',
#  'https://www.csulb.edu/college-of-education/research-and-grants',
#  'https://www.csulb.edu/college-of-education/article/college-of-ed-professor-student-honored-for-work-supporting-black-grad',
#  'https://www.csulb.edu/college-of-education/college-of-education-faculty-research-stories',
#  'https://www.csulb.edu/college-of-education/admissions-and-how-to-apply',
#  'https://www.csulb.edu/college-of-education/graduate-certificate-applied-disability-studies',
#  'https://www.csulb.edu/college-of-education/become-a-teacher',
#  'https://www.csulb.edu/college-of-education/educational-leadership',
#  'https://www.csulb.edu/college-of-education/ced-study-abroad-programs',
#  'https://www.csulb.edu/college-of-education/technology',
#  'https://www.csulb.edu/college-of-education/credential-center/career-technical-education-teaching-credential',
#  'https://www.csulb.edu/college-of-education/master-of-science-special-education',
#  'https://www.csulb.edu/college-of-education/college-of-education-student-organizations',
#  'https://www.csulb.edu/college-of-education/office-of-clinical-practice-ocp',
#  'https://www.csulb.edu/college-of-education/credential-center',
#  'https://www.csulb.edu/college-of-education/graduate-certificate-community-college',
#  'https://www.csulb.edu/college-of-education/college-governance',
#  'https://www.csulb.edu/college-of-education/article/the-winner-of-our-diploma-frame-giveaway',
#  'https://www.csulb.edu/college-of-education/college-of-education-faculty-staff']
# 80
# 80

# %%
# for every url in "observed_links" download the images contained on that page and store it in "scraped_images" folder
for i in range(len(observed_links)):
    main(observed_links[i], os.path.join(os.getcwd(), "scraped_images"))
# Out:
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 5.35MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.41MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 9.80MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\banner_ced_teacer-alc-betina-class-11-b.jpg: 100%|██████████| 133k/133k [00:00<00:00, 2.50MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 5.33MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 3.58MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.44MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.69MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 5.35MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.38MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 5.95MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.69MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.62MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<00:00, 11008.67it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.03MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.40MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 9.84MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\banner_ced_nina-flores-5b-students-in-counseling-session.jpg: 100%|██████████| 150k/150k [00:00<00:00, 2.67MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 8.98MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.41MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 7.33MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.36MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\banner_ced_thy-148-teacher-middle-classroom.jpg: 100%|██████████| 95.6k/95.6k [00:00<00:00, 3.32MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 3.19MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.64MB/s]
# Extracting images: 100%|██████████| 12/12 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.68MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.03MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 29.3MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.41MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.01MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\external_verification.php: 100%|██████████| 199/199 [00:00<00:00, 200kB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.49MB/s]
# Extracting images: 100%|██████████| 12/12 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.03MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 5.52MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 5.78MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\banner_ced_teacher-guitar.jpg: 100%|██████████| 146k/146k [00:00<00:00, 2.29MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\application-pdf.png: 100%|██████████| 346/346 [00:00<00:00, 346kB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 5.95MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.68MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 5.52MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 9.81MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\banner_ced_thy-148-teacher-middle-classroom.jpg: 100%|██████████| 95.6k/95.6k [00:00<00:00, 3.32MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 8
B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 5.33MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.65MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<00:00, 21866.04it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 4.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 5.52MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.40MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 14.8MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.19MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 3.21MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.68MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.62MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.69MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.39MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 9.83MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.55MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 4.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.04MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.62MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 5.91MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 9.84MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.45MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 5.95MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.56MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.68MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 4.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 5.52MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 4.94MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.40MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.15MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.48MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.69MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.59MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.40MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.26MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 2.58MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.03MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 4.49MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.04MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.57MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<00:00, 11027.09it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.03MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 11.0MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 5.91MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.40MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\Mario.jpg: 100%|██████████| 1.00M/1.00M [00:00<00:00, 6.88MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 4.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 8.98MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.71MB/s]
# Extracting images: 100%|██████████| 11/11 [00:00<00:00, 11024.45it/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 2.02MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\logo-footer.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.04MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\mobile-footer-logo.png: 100%|██████████| 10.7k/10.7k [00:00<00:00, 5.52MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.41MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-black.png: 100%|██████████| 14.4k/14.4k [00:00<00:00, 7.37MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\CED%20Campus9.jpg: 100%|██████████| 289k/289k [00:00<00:00, 3.07MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\tr: 0.00B [00:00, ?B/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb_wordmark_blk-59.svg: 100%|██████████| 7.84k/7.84k [00:00<00:00, 8.04MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\csulb.svg: 100%|██████████| 8.75k/8.75k [00:00<00:00, 8.99MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\lb.svg: 100%|██████████| 3.94k/3.94k [00:00<00:00, 4.05MB/s]
# Downloading e:\github\algorithmic_bias\env\web scraping\scraped_images\wordmark-white.png: 100%|██████████| 45.0k/45.0k [00:00<00:00, 1.56MB/s]

# %%
# count the files in the folder that was the target of my downloads
dir_path = "scraped_images"
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# Out:
# File count: 111

# %%
# observed_links_lvl2 is the nested list described above
observed_links_lvl2 = [None]*len(observed_links)
for i in range(len(observed_links)):
    observed_links_lvl2[i] = get_embedded_url(observed_links[i])

# %%
# count the number of links in the nested
for i in range(len(observed_links_lvl2)):
    print(len(observed_links_lvl2[i]))
    
display(observed_links_lvl2[:2])
# Out:
# 78
# 67
# 65
# 83
# 78
# 80
# 79
# 68
# 85
# 65
# 80
# 79
# 82
# 80
# 94
# 70
# 65
# 68
# 65
# 77
# 66
# 65
# 73
# 75
# 72
# 65
# 70
# 81
# 67
# 79
# 65
# 97
# 73
# 67
# 73
# 72
# 66
# 91
# 79
# 65
# 79
# 71
# 66
# 79
# 67
# 69
# 69
# 77
# 71
# 67
# 79
# 77
# 86
# 98
# 78
# 82
# 80
# 77
# 72
# 68
# 72
# 85
# 76
# 65
# 66
# 71
# 69
# 68
# 73
# 67
# 73
# 79
# 79
# 65
# 79
# 84
# 65
# 69
# 65
# 188
# [['https://www.csulb.edu/college-of-education/teacher-education',
#   'https://www.csulb.edu/college-of-education/assessment-office',
#   'https://www.csulb.edu/college-of-education/education-specialist-credential-program-escp',
#   'https://www.csulb.edu/college-of-education/teacher-education/programs-to-become-a-teacher',
#   'https://www.csulb.edu/college-of-education/community-clinic-for-counseling-and-educational-services',
#   'https://www.csulb.edu/college-of-education/liberal-studies',
#   'https://www.csulb.edu/college-of-education/dual-language-development',
#   'https://www.csulb.edu/college-of-education/overview-of-scholarships-financial-aid',
#   'https://www.csulb.edu/college-of-education/multiple-subject-credential-program-mscp',
#   'https://www.csulb.edu/college-of-education/form/share-your-faculty-andor-staff-updates-and-accolades',
#   'https://www.csulb.edu/college-of-education/counseling-psychology',
#   'https://www.csulb.edu/college-of-education/credential-center/careers-education',
#   'https://www.csulb.edu/college-of-education/assessment-office/ctc-accreditation-documents',
#   'https://www.csulb.edu/college-of-education/curriculum-and-instruction',
#   'https://www.csulb.edu/college-of-education/graduate-studies-office',
#   'https://www.csulb.edu/college-of-education/alumni',
#   'https://www.csulb.edu/college-of-education/educational-technology-and-media-leadership',
#   'https://www.csulb.edu/college-of-education/school-psychology',
#   'https://www.csulb.edu/college-of-education',
#   'https://www.csulb.edu/college-of-education/college-of-education-student-organizations',
#   'https://www.csulb.edu/college-of-education/teacher-librarian-services-credential',
#   'https://www.csulb.edu/college-of-education/master-of-science-special-education',
#   'https://www.csulb.edu/college-of-education/liberal-studies/prospective-students',
#   'https://www.csulb.edu/college-of-education/office-of-clinical-practice-ocp',
#   'https://www.csulb.edu/college-of-education/student-development-higher-education',
#   'https://www.csulb.edu/college-of-education/single-subject-credential-program-sscp',
#   'https://www.csulb.edu/college-of-education/credential-center',
#   'https://www.csulb.edu/college-of-education/long-beach-trauma-recovery-center',
#   'https://www.csulb.edu/college-of-education/office-of-the-dean/college-and-university-tools',
#   'https://www.csulb.edu/college-of-education/graduate-certificate-community-college',
#   'https://www.csulb.edu/college-of-education/mathematics-education',
#   'https://www.csulb.edu/college-of-education/assessment-office/unit-assessment-system',
#   'https://www.csulb.edu/college-of-education/make-an-appointment',
#   'https://www.csulb.edu/college-of-education/advanced-studies-education-and-counseling',
#   'https://www.csulb.edu/college-of-education/center-for-evaluation-and-educational-effectiveness',
#   'https://www.csulb.edu/college-of-education/liberal-studies/liberal-studies-program',
#   'https://www.csulb.edu/college-of-education/teacher-preparation-advising-center-tpac',
#   'https://www.csulb.edu/college-of-education/urban-dual-credential-program-udcp',
#   'https://www.csulb.edu/college-of-education/employment-opportunities',
#   'https://www.csulb.edu/college-of-education/outreach-and-recruitment/program-information-sessions',
#   'https://www.csulb.edu/college-of-education/college-governance',
#   'https://www.csulb.edu/college-of-education/faculty-resources-and-support',
#   'https://www.csulb.edu/college-of-education/research-and-grants',
#   'https://www.csulb.edu/college-of-education/hsi-caminos-project-caminantes-for-education',
#   'https://www.csulb.edu/college-of-education/college-of-education-faculty-staff',
#   'https://www.csulb.edu/college-of-education/credential-center/credential-programs',
#   'https://www.csulb.edu/college-of-education/college-of-education-faculty-research-stories']]

# %%
# flatten observed_links2
from itertools import chain
lvl2_flat = list(chain.from_iterable(observed_links_lvl2))

# keep only unique urls
lvl2_flat_unique = list(set(lvl2_flat))

# %%
# inspect size of lists created above
display(len(lvl2_flat))
display(len(lvl2_flat_unique))

# count the number of "valid" or executable links in the observed
count = 0
for i in lvl2_flat_unique:
    if is_valid(i):
        count += 1
count
# Out:
# 6039
# 747
# 747

# %%
len(list(set([observed_links, lvl2_flat_unique])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 len(list(set([observed_links, lvl2_flat_unique])))
#
# TypeError: unhashable type: 'list'

# %%
from collections import Counter
to_be_downloaded = list((Counter(lvl2_flat_unique)-Counter(observed_links)).elements())
display(len(to_be_downloaded))
# Out:
# 667
